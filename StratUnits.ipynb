# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import datasets
import matplotlib.pyplot as plt
from seismicFunctions import readSEGY
from sklearn.neighbors import NearestNeighbors
import hdbscan
from sklearn import preprocessing

# %%
#Load seismic data/attributes

import pickle
f = open('seismic_volume.pckl', 'rb') 
seismic_volume = pickle.load(f) 
f.close()

f = open('texture_descriptor.pckl', 'rb') 
texture_descriptor = pickle.load(f) 
f.close()

#from TextureDescriptor import LBP_3D_mixmax_corner
#texture_descriptor=LBP_3D_mixmax_corner(seismic_volume)
from StratUnits_functions import trimSeismicAmplitudes
seismic_data = trimSeismicAmplitudes(seismic_data, 99.7)

# %%
plt.imshow(seismic_volume[:,50,:], cmap='gray')
plt.show()

plt.imshow(texture_descriptor[:,50,:])
plt.show()

# %%
import time
from StratUnits_functions import *

start = time.time()

step=10
window_size=[50, 50, 50]
min_cluster_fraction=25

units= iteratively_identify_stratUnits(seismic_volume, texture_descriptor, window_size, step, min_cluster_fraction)

stop = time.time()
t=(stop-start)/60
print(' time in minutes: ', t)
# Out:
# C:\Users\Aina\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# feature vectors 252288
# min_cluster_size 10091
# iteration 1
# first iteration....
# 90928
# Final iteration
# 2 cubes are returned
#  time in minutes:  89.5214187502861
